# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
lst=os.listdir('C:\\Users\\14692\\Documents\\Python\\Formula1')
lst
# Out:
# ['circuits.csv',
#  'combined_csv.csv',
#  'constructors.csv',
#  'constructor_results.csv',
#  'constructor_standings.csv',
#  'drivers.csv',
#  'driver_standings.csv',
#  'lap_times.csv',
#  'pit_stops.csv',
#  'qualifying.csv',
#  'races.csv',
#  'results.csv',
#  'seasons.csv',
#  'status.csv']

# %%
circuits=pd.read_csv('circuits.csv')
combined_csv=pd.read_csv('combined_csv.csv')
constructors=pd.read_csv('constructors.csv')
constructor_results=pd.read_csv('constructor_results.csv')
constructor_standings=pd.read_csv('constructor_standings.csv')
drivers=pd.read_csv('drivers.csv')
driver_standings=pd.read_csv('driver_standings.csv')
lap_times=pd.read_csv('lap_times.csv')
pit_stops=pd.read_csv('pit_stops.csv')
qualifying=pd.read_csv('qualifying.csv')
races=pd.read_csv('races.csv')
results=pd.read_csv('results.csv')
seasons=pd.read_csv('seasons.csv')
status=pd.read_csv('status.csv')
# Out:
# C:\Users\14692\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,2,3,5,8,9,10,12,14,15,16,17,18,24,25,26,27,28,30,32,33,34,35,38,41,44,45,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
circuits.head()
#print(circuits.shape) #(74, 9)
circuits.set_index('circuitId', inplace=True)
# Out:
#             circuitRef                            name      location  \
# circuitId
# 1          albert_park  Albert Park Grand Prix Circuit     Melbourne
# 2               sepang    Sepang International Circuit  Kuala Lumpur
# 3              bahrain   Bahrain International Circuit        Sakhir
# 4            catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 5             istanbul                   Istanbul Park      Istanbul
#
#              country       lat        lng alt
# circuitId
# 1          Australia -37.84970  144.96800  10
# 2           Malaysia   2.76083  101.73800  \N
# 3            Bahrain  26.03250   50.51060  \N
# 4              Spain  41.57000    2.26111  \N
# 5             Turkey  40.95170   29.40500  \N

# %%
circuits.drop('url', axis=1, inplace=True)

# %%
# many of the records are empty so its of not much use
combined_csv.dropna(how='any').head()
#print(combined_csv.shape) #571732, 49
# Out:
# Empty DataFrame
# Columns: [alt, circuitId, circuitRef, code, constructorId, constructorRef, constructorResultsId, constructorStandingsId, country, date, dob, driverId, driverRef, driverStandingsId, duration, fastestLap, fastestLapSpeed, fastestLapTime, forename, grid, lap, laps, lat, lng, location, milliseconds, name, nationality, number, points, position, positionOrder, positionText, q1, q2, q3, qualifyId, raceId, rank, resultId, round, status, statusId, stop, surname, time, url, wins, year]
# Index: []
#
# [0 rows x 49 columns]

# %%
#print(constructors.shape) #209,5
constructors.drop('url', axis=1, inplace=True)
constructors.head()
# Out:
#    constructorId constructorRef        name nationality
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian

# %%
df=df.merge(constructors, on='constructorId',how='inner')

# %%
constructor_results.head()
#constructor_results.shape #(11560, 5)
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0     \N
# 1                     2      18              2     8.0     \N
# 2                     3      18              3     9.0     \N
# 3                     4      18              4     5.0     \N
# 4                     5      18              5     2.0     \N

# %%
constructor_standings.head()
# #constructor_standings.shape #(12316, 7)
constructor_standings[(constructor_standings['position']==constructor_standings['position'])]
# #position and positionText columns represent the same values so dropping positionText column
constructor_standings.set_index('constructorStandingsId', inplace=True)
# Out:
#                         raceId  constructorId  points  position positionText  \
# constructorStandingsId
# 1                           18              1    14.0         1            1
# 2                           18              2     8.0         3            3
# 3                           18              3     9.0         2            2
# 4                           18              4     5.0         4            4
# 5                           18              5     2.0         5            5
#
#                         wins
# constructorStandingsId
# 1                          1
# 2                          0
# 3                          0
# 4                          0
# 5                          0

# %%
drivers.head()
#drivers.shape #(847, 9)
#drivers.drop('url',axis=1,inplace=True)
drivers.set_index('driverId', inplace=True)
# Out:
#            driverRef number code  forename     surname         dob nationality
# driverId
# 1           hamilton     44  HAM     Lewis    Hamilton  1985-01-07     British
# 2           heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10      German
# 3            rosberg      6  ROS      Nico     Rosberg  1985-06-27      German
# 4             alonso     14  ALO  Fernando      Alonso  1981-07-29     Spanish
# 5         kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19     Finnish

# %%
driver_standings.head()
#(32566, 7)
driver_standings.set_index('driverStandingsId', inplace=True)
# Out:
#                    raceId  driverId  points  position positionText  wins
# driverStandingsId
# 1                      18         1    10.0         1            1     1
# 2                      18         2     8.0         2            2     0
# 3                      18         3     6.0         3            3     0
# 4                      18         4     5.0         4            4     0
# 5                      18         5     4.0         5            5     0

# %%
lap_times.head()
#(472504, 6)
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
pit_stops.head()
#(7436, 7)
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
qualifying.head()
#(8354, 9)
# Out:
# 8344    8368
# 8345    8369
# 8346    8370
# 8347    8371
# 8348    8372
# 8349    8373
# 8350    8374
# 8351    8375
# 8352    8376
# 8353    8377
# Name: qualifyId, dtype: int64

# %%
#qualifying["q1"]= pd.to_datetime(qualifying["q1"]) 
qualifying[~qualifying.isna()]['q2'].head(10)
# Out:
# 0    1:25.187
# 1    1:25.315
# 2    1:25.452
# 3    1:25.691
# 4    1:25.518
# 5    1:26.101
# 6    1:26.059
# 7    1:26.063
# 8    1:26.164
# 9    1:25.842
# Name: q2, dtype: object

# %%
qualifying['q1'] = qualifying['q1'].astype('datetime64[ns]') 

#Conver to date time format and sum q1,q2 & q3

# %%
races.head() #(1040, 8)
races.drop('url', axis=1,inplace=True)
# Out:
#    raceId  year  round  circuitId                   name        date      time
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29  06:00:00
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05  09:00:00
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19  07:00:00
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26  12:00:00
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10  12:00:00

# %%
results.head(10) #(24620, 18)
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
# 5         6      18         6              3      8    13        6
# 6         7      18         7              5     14    17        7
# 7         8      18         8              6      1    15        8
# 8         9      18         9              2      4     2       \N
# 9        10      18        10              7     12    18       \N
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# ...

# %%
#Every useful feature is integrated in the df dataframe.

df = pd.merge(results, drivers, on='driverId', how='inner')
df.drop(['number_x','positionText','number_y','position','dob','code','nationality_y','nationality_y'], axis=1,inplace=True)
df.head()
# Out:
#    resultId  raceId  driverId  constructorId  grid  positionOrder  points  \
# 0         1      18         1              1     1              1    10.0
# 1        27      19         1              1     9              5     4.0
# 2        69      21         1              1     5              3     6.0
# 3        90      22         1              1     3              2     8.0
# 4       109      23         1              1     3              1    10.0
#
#    laps         time milliseconds  ... fastestLapTime fastestLapSpeed  \
# 0    58  1:34:50.616      5690616  ...       1:27.452         218.300
# 1    56      +46.548      5525103  ...       1:35.462         209.033
# 2    66       +4.187      5903238  ...       1:22.017         204.323
# 3    58       +3.779      5213230  ...       1:26.529         222.085
# 4    76  2:00:42.742      7242742  ...       1:18.510         153.152
#
#   statusId driverRef  forename   surname nationality_x    status  \
# ...

# %%
#No use of it

seasons.head() #(71, 2)
# Out:
#    year                                                url
# 0  2009  https://en.wikipedia.org/wiki/2009_Formula_One...
# 1  2008  https://en.wikipedia.org/wiki/2008_Formula_One...
# 2  2007  https://en.wikipedia.org/wiki/2007_Formula_One...
# 3  2006  https://en.wikipedia.org/wiki/2006_Formula_One...
# 4  2005  https://en.wikipedia.org/wiki/2005_Formula_One...

# %%
df_fastlap_drivers=df[df.fastestLapSpeed.sort_values(ascending=True)]
df_fastlap_drivers_lst=df_fastlap_drivers.groupby(['driverRef'])['driverRef'].
df_fastlap_drivers_lst.sort_values(ascending=False)
# Out:
# 10455    100.615
# 5079     101.399
# 8265     101.884
# 3261     108.410
# 6766     112.116
#           ...
# 11887         \N
# 11886         \N
# 11885         \N
# 11901         \N
# 24619         \N
# Name: fastestLapSpeed, Length: 24620, dtype: object

# %%
df[df['fastestLapSpeed']=='100.615']
# Out:
#        resultId  raceId  driverId  constructorId  grid position  \
# 10455     22259     905        20              9     4       \N
#
#        positionOrder  points  laps time  ... driverRef code   forename  \
# 10455             20     0.0     5   \N  ...    vettel  VET  Sebastian
#
#       surname         dob  nationality_x status constructorRef      name  \
# 10455  Vettel  1987-07-03         German  Turbo       red_bull  Red Bull
#
#       nationality_y
# 10455      Austrian
#
# [1 rows x 26 columns]

# %% [markdown]
# It Shows that Sebastian Vettel completed the fastest lap among all the drivers

# %%
# status_dict=status.to_dict()
# df['status']=df['statusId'].map(status_dict)
df=df.merge(status,on='statusId', how='inner')

# %%
df['status'].unique()
# Out:
# array([nan], dtype=object)

# %%
#cnc==constructor_name_count
cnc=df.groupby(['name'])['name'].count()
cnc=cnc.to_frame()
cnc.rename(columns={'name':'count'})
ac=cnc.index
cnc['cons_names']=ac

# %%
# cnc.set_index('cons_names',inplace=True)
cnc.sort_values(by='name', ascending=False).head(5).plot(kind='bar')

# %% [markdown]
# It shows Ferrari has won the maximum number of titles followed by McLaren, Williams, Tyrrell, Team Lotus in the top 5

# %%
df.groupby(['driverRef'])['status','constructorRef'].count().sort_values(by='status',ascending=False)
# Out:
#                     status  constructorRef
# driverRef
# barrichello            326             326
# raikkonen              315             315
# alonso                 314             314
# button                 309             309
# michael_schumacher     308             308
# ...                    ...             ...
# constantine              1               1
# scott_Brown              1               1
# scotti                   1               1
# hasemi                   1               1
# Cannoc                   1               1
#
# [847 rows x 2 columns]
